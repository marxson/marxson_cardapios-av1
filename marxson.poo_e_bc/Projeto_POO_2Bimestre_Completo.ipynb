# %% [markdown]
# # 📘 Projeto de Programação Orientada a Objetos – 2º Bimestre
#
# **Nome do Aluno: marxson moraira da cruz
#
# **Turma:2a ti
#
# **Tema Escolhido: sistema que monte cardápios escolares,

# %% [markdown]
# Lembre-se esse projeto deve ser personalizado, todas as classe e metodos devem ter uma referencia ao seu nome, exemplo:
#
# class Carro_Fabio:
#
#     def __init__(self, tipo, cor, rodas):
#         self.tipo = tipo
#         self.cor = cor
#         self.rodas = rodas
#
#     def alterar_cor_Fabio(self, nova_cor):
#         self.cor = nova_cor
#         return self.cor

# %% [markdown]
# ## PARTE 1 – Classe Principal e Objetos
#
# **Tarefas:**
# - Definir e criar a classe principal com pelo menos 3 atributos.
# - Implementar o método construtor (`__init__`).
# - Criar pelo menos 2 objetos da classe principal.
# - Implementar um método de exibição de dados.
#
# **Código:**

# %%
class Prato:
    # Construtor (__init__) para inicializar os atributos da classe
    def __init__(self, nome, ingredientes, calorias):
        self.nome = nome              # Atributo 1: nome do prato
        self.ingredientes = ingredientes  # Atributo 2: ingredientes do prato
        self.calorias = calorias        # Atributo 3: calorias do prato

    # Método para exibir os dados do prato
    def exibir_dados(self):
        print(f"Prato: {self.nome}")
        print(f"Ingredientes: {self.ingredientes}")
        print(f"Calorias: {self.calorias} kcal")

# Criando dois objetos da classe Prato
prato1 = Prato("Arroz com Feijão", "Arroz, Feijão, Carne, Salada", 450)
prato2 = Prato("Macarrão à Bolonhesa", "Macarrão, Carne Moída, Molho de Tomate, Queijo", 600)

# Exibindo os dados dos pratos
print("Detalhes do prato 1:")
prato1.exibir_dados()

print("\nDetalhes do prato 2:")
prato2.exibir_dados()

# %% [markdown]
# ## PARTE 2 – Métodos e Herança
#
# **Tarefas:**
# - Criar pelo menos 2 métodos de ação para a classe principal.
# - Criar uma subclasse herdando da classe principal.
# - Adicionar pelo menos 1 novo atributo e 1 novo método exclusivo na subclasse.
# - Utilizar `super()` no construtor da subclasse.
#
# **Código:**

# %%
# Classe principal Prato
class Prato:
    # Construtor (__init__) para inicializar os atributos da classe
    def __init__(self, nome, ingredientes, calorias):
        self.nome = nome              # Atributo 1: nome do prato
        self.ingredientes = ingredientes  # Atributo 2: ingredientes do prato
        self.calorias = calorias        # Atributo 3: calorias do prato

    # Método para exibir os dados do prato
    def exibir_dados(self):
        print(f"Prato: {self.nome}")
        print(f"Ingredientes: {self.ingredientes}")
        print(f"Calorias: {self.calorias} kcal")

    # Método de ação 1: Atualizar calorias
    def atualizar_calorias(self, novas_calorias):
        self.calorias = novas_calorias
        print(f"As calorias do prato {self.nome} foram atualizadas para {self.calorias} kcal.")

    # Método de ação 2: Adicionar ingredientes
    def adicionar_ingredientes(self, novos_ingredientes):
        self.ingredientes += ", " + novos_ingredientes
        print(f"Novos ingredientes adicionados ao prato {self.nome}: {novos_ingredientes}")

# Subclasse PratoVegetariano herda de Prato
class PratoVegetariano(Prato):
    # Construtor da subclasse (usando super() para herdar da classe pai)
    def __init__(self, nome, ingredientes, calorias, tipo_vegetariano):
        super().__init__(nome, ingredientes, calorias)  # Herdando atributos da classe Pai
        self.tipo_vegetariano = tipo_vegetariano  # Novo atributo exclusivo da subclasse

    # Novo método exclusivo da subclasse
    def exibir_tipo_vegetariano(self):
        print(f"O prato {self.nome} é do tipo vegetariano: {self.tipo_vegetariano}")

# Criando objetos da classe Prato
prato1 = Prato("Arroz com Feijão", "Arroz, Feijão, Carne, Salada", 450)
prato2 = Prato("Macarrão à Bolonhesa", "Macarrão, Carne Moída, Molho de Tomate, Queijo", 600)

# Criando objetos da subclasse PratoVegetariano
prato_vegetariano1 = PratoVegetariano("Feijoada Vegetariana", "Feijão, Tofu, Legumes", 350, "Vegana")
prato_vegetariano2 = PratoVegetariano("Lasanha de Abobrinha", "Abobrinha, Queijo, Molho de Tomate, Espinafre", 400, "Vegetariana")

# Exibindo dados dos pratos
print("\nDetalhes do prato 1 (Prato comum):")
prato1.exibir_dados()

print("\nDetalhes do prato 2 (Prato comum):")
prato2.exibir_dados()

# Atualizando dados do prato
prato1.atualizar_calorias(500)
prato2.adicionar_ingredientes("Azeitona")

# Exibindo dados dos pratos vegetarianos
print("\nDetalhes do prato 1 (Prato Vegetariano):")
prato_vegetariano1.exibir_dados()
prato_vegetariano1.exibir_tipo_vegetariano()

print("\nDetalhes do prato 2 (Prato Vegetariano):")
prato_vegetariano2.exibir_dados()
prato_vegetariano2.exibir_tipo_vegetariano()

# %% [markdown]
# ## PARTE 3 – Encapsulamento e Abstração
#
# **Tarefas:**
# - Tornar pelo menos 1 atributo da classe principal privado (`__atributo`).
# - Criar métodos `get` e `set` para o atributo privado.
# - Implementar um método que contenha lógica interna (ex: cálculo, verificação).
#
# **Código:**

# %%
class Prato:
    # Construtor (__init__) para inicializar os atributos da classe
    def __init__(self, nome, ingredientes, calorias):
        self.nome = nome               # Atributo 1: nome do prato
        self.ingredientes = ingredientes # Atributo 2: ingredientes do prato
        self.__calorias = calorias      # Atributo 3: calorias (privado)

    # Métodos get e set para o atributo privado __calorias
    def get_calorias(self):
        return self.__calorias

    def set_calorias(self, novas_calorias):
        if novas_calorias > 0:  # Validando se as calorias são positivas
            self.__calorias = novas_calorias
            print(f"As calorias do prato {self.nome} foram atualizadas para {self.__calorias} kcal.")
        else:
            print("Valor de calorias inválido! Deve ser maior que zero.")

    # Método de lógica interna: Verificar se o prato é saudável
    def verificar_saudavel(self):
        if self.__calorias <= 500:
            print(f"O prato {self.nome} é saudável.")
        else:
            print(f"O prato {self.nome} não é saudável.")

    # Método para exibir os dados do prato
    def exibir_dados(self):
        print(f"Prato: {self.nome}")
        print(f"Ingredientes: {self.ingredientes}")
        print(f"Calorias: {self.get_calorias()} kcal")

# Criando objetos da classe Prato
prato1 = Prato("Arroz com Feijão", "Arroz, Feijão, Carne, Salada", 450)
prato2 = Prato("Macarrão à Bolonhesa", "Macarrão, Carne Moída, Molho de Tomate, Queijo", 600)

# Exibindo dados do prato
print("\nDetalhes do prato 1 (Prato comum):")
prato1.exibir_dados()

print("\nDetalhes do prato 2 (Prato comum):")
prato2.exibir_dados()

# Alterando calorias utilizando o set
prato1.set_calorias(550)  # Atualizando com um valor válido
prato1.set_calorias(-100)  # Tentando atualizar com um valor inválido

# Verificando se o prato é saudável
prato1.verificar_saudavel()
prato2.verificar_saudavel()

# %% [markdown]
# ## PARTE 4 – Polimorfismo e Banco de Dados
#
# **Tarefas:**
# - Implementar polimorfismo: sobrescrever um método na subclasse.
# - Integrar o sistema com banco de dados (MySQL ou SQLite).
# - Implementar inserção (INSERT), consulta (SELECT) e exclusão (DELETE) de registros no banco de dados.
#
# **Código:**

# %%
import sqlite3

# --------------------------------------------------------------
# Função para conectar ao banco de dados SQLite
def conectar_banco():
    return sqlite3.connect('cardapio_escolar.db')

# --------------------------------------------------------------
# Função para criar a tabela no banco de dados
def criar_tabela():
    conn = conectar_banco()
    cursor = conn.cursor()
    cursor.execute('''
    CREATE TABLE IF NOT EXISTS pratos (
        id INTEGER PRIMARY KEY AUTOINCREMENT,
        nome TEXT NOT NULL,
        ingredientes TEXT NOT NULL,
        calorias INTEGER NOT NULL,
        saudavel BOOLEAN NOT NULL
    )
    ''')
    conn.commit()
    conn.close()

# --------------------------------------------------------------
# Classe principal Prato
class Prato:
    def __init__(self, nome, ingredientes, calorias):
        # Atributos de instância
        self.nome = nome
        self.ingredientes = ingredientes
        self.__calorias = calorias  # Atributo privado

    # Métodos get e set para o atributo privado __calorias
    def get_calorias(self):
        return self.__calorias

    def set_calorias(self, novas_calorias):
        if novas_calorias > 0:  # Validando as calorias
            self.__calorias = novas_calorias
            print(f"As calorias do prato '{self.nome}' foram atualizadas para {self.__calorias} kcal.")
        else:
            print("Valor de calorias inválido! Deve ser maior que zero.")

    # Método para verificar se o prato é saudável
    def verificar_saudavel(self):
        return self.__calorias <= 500

    # Método para exibir dados do prato (polimorfismo será aplicado na subclasse)
    def exibir_dados(self):
        print(f"\nPrato: {self.nome}")
        print(f"Ingredientes: {self.ingredientes}")
        print(f"Calorias: {self.__calorias} kcal")
    
    # Método para inserir prato no banco de dados
    def inserir_no_banco(self):
        conn = conectar_banco()
        cursor = conn.cursor()
        cursor.execute('''
        INSERT INTO pratos (nome, ingredientes, calorias, saudavel)
        VALUES (?, ?, ?, ?)
        ''', (self.nome, self.ingredientes, self.__calorias, self.verificar_saudavel()))
        conn.commit()
        conn.close()
        print(f"\nPrato '{self.nome}' inserido no banco de dados.")

    # Método para excluir prato do banco de dados
    @staticmethod
    def excluir_do_banco(prato_id):
        conn = conectar_banco()
        cursor = conn.cursor()
        cursor.execute('DELETE FROM pratos WHERE id = ?', (prato_id,))
        conn.commit()
        conn.close()
        print(f"\nPrato com ID {prato_id} excluído do banco de dados.")

    # Método para consultar pratos no banco de dados
    @staticmethod
    def consultar_no_banco():
        conn = conectar_banco()
        cursor = conn.cursor()
        cursor.execute('SELECT * FROM pratos')
        pratos = cursor.fetchall()
        if pratos:
            for prato in pratos:
                print(f"\nID: {prato[0]}, Nome: {prato[1]}, Ingredientes: {prato[2]}, Calorias: {prato[3]}, Saudável: {'Sim' if prato[4] else 'Não'}")
        else:
            print("\nNenhum prato encontrado no banco de dados.")
        conn.close()

# --------------------------------------------------------------
# Função para cadastrar um novo prato
def cadastrar_prato():
    print("\n--- Cadastro de Novo Prato ---")
    nome = input("Digite o nome do prato: ")
    ingredientes = input("Digite os ingredientes do prato: ")
    calorias = int(input("Digite a quantidade de calorias do prato: "))

    prato = Prato(nome, ingredientes, calorias)
    prato.inserir_no_banco()

# --------------------------------------------------------------
# Função para consultar pratos por calorias
def consultar_pratos_por_calorias():
    print("\n--- Consulta de Pratos por Calorias ---")
    faixa_calorias_min = int(input("Digite o valor mínimo de calorias: "))
    faixa_calorias_max = int(input("Digite o valor máximo de calorias: "))
    
    conn = conectar_banco()
    cursor = conn.cursor()
    cursor.execute('''
    SELECT * FROM pratos WHERE calorias BETWEEN ? AND ?
    ''', (faixa_calorias_min, faixa_calorias_max))
    
    pratos = cursor.fetchall()
    if pratos:
        for prato in pratos:
            print(f"\nID: {prato[0]}, Nome: {prato[1]}, Ingredientes: {prato[2]}, Calorias: {prato[3]}, Saudável: {'Sim' if prato[4] else 'Não'}")
    else:
        print("\nNenhum prato encontrado dentro dessa faixa de calorias.")
    conn.close()

# --------------------------------------------------------------
# Função para excluir um prato
def excluir_prato():
    print("\n--- Exclusão de Prato ---")
    prato_id = int(input("Digite o ID do prato que deseja excluir: "))
    Prato.excluir_do_banco(prato_id)

# --------------------------------------------------------------
# Função para atualizar as calorias de um prato
def atualizar_calorias():
    print("\n--- Atualização de Calorias de Prato ---")
    prato_id = int(input("Digite o ID do prato que deseja atualizar: "))
    novas_calorias = int(input("Digite a nova quantidade de calorias: "))
    
    conn = conectar_banco()
    cursor = conn.cursor()
    cursor.execute('''
    UPDATE pratos SET calorias = ? WHERE id = ?
    ''', (novas_calorias, prato_id))
    conn.commit()
    conn.close()
    print(f"\nCalorias do prato de ID {prato_id} atualizadas para {novas_calorias} kcal.")

# --------------------------------------------------------------
# Função para testar o sistema com entradas do usuário
def testar_sistema():
    while True:
        print("\nEscolha uma opção:")
        print("1. Cadastrar novo prato")
        print("2. Consultar pratos por calorias")
        print("3. Excluir prato")
        print("4. Atualizar calorias de um prato")
        print("5. Consultar todos os pratos")
        print("6. Sair")

        opcao = int(input("Digite o número da opção desejada: "))

        if opcao == 1:
            cadastrar_prato()
        elif opcao == 2:
            consultar_pratos_por_calorias()
        elif opcao == 3:
            excluir_prato()
        elif opcao == 4:
            atualizar_calorias()
        elif opcao == 5:
            Prato.consultar_no_banco()
        elif opcao == 6:
            print("Saindo...")
            break
        else:
            print("\nOpção inválida! Tente novamente.")

# --------------------------------------------------------------
# Função principal para executar o sistema
if __name__ == "__main__":
    # Criando a tabela no banco de dados
    criar_tabela()

    # Testando a funcionalidade do sistema com inputs interativos
    testar_sistema()

# %% [markdown]
# ## PARTE 5 – Projeto Final e Organização
#
# **Tarefas:**
# - Consolidar todas as partes do projeto em um único script organizado.
# - Comentar o código explicando cada parte.
# - Testar todas as funcionalidades.
#
# **Código:**

# %%
import sqlite3

# --------------------------------------------------------------
# Função para conectar ao banco de dados SQLite
def conectar_banco():
    return sqlite3.connect('cardapio_escolar.db')

# --------------------------------------------------------------
# Função para criar a tabela no banco de dados
def criar_tabela():
    conn = conectar_banco()
    cursor = conn.cursor()
    cursor.execute('''
    CREATE TABLE IF NOT EXISTS pratos (
        id INTEGER PRIMARY KEY AUTOINCREMENT,
        nome TEXT NOT NULL,
        ingredientes TEXT NOT NULL,
        calorias INTEGER NOT NULL,
        saudavel BOOLEAN NOT NULL
    )
    ''')
    conn.commit()
    conn.close()

# --------------------------------------------------------------
# Classe principal Prato
class Prato:
    def __init__(self, nome, ingredientes, calorias):
        # Atributos de instância
        self.nome = nome
        self.ingredientes = ingredientes
        self.__calorias = calorias  # Atributo privado

    # Métodos get e set para o atributo privado __calorias
    def get_calorias(self):
        return self.__calorias

    def set_calorias(self, novas_calorias):
        if novas_calorias > 0:  # Validando as calorias
            self.__calorias = novas_calorias
            print(f"As calorias do prato '{self.nome}' foram atualizadas para {self.__calorias} kcal.")
        else:
            print("Valor de calorias inválido! Deve ser maior que zero.")

    # Método para verificar se o prato é saudável
    def verificar_saudavel(self):
        return self.__calorias <= 500

    # Método para exibir dados do prato (polimorfismo será aplicado na subclasse)
    def exibir_dados(self):
        print(f"Prato: {self.nome}")
        print(f"Ingredientes: {self.ingredientes}")
        print(f"Calorias: {self.__calorias} kcal")
    
    # Método para inserir prato no banco de dados
    def inserir_no_banco(self):
        conn = conectar_banco()
        cursor = conn.cursor()
        cursor.execute('''
        INSERT INTO pratos (nome, ingredientes, calorias, saudavel)
        VALUES (?, ?, ?, ?)
        ''', (self.nome, self.ingredientes, self.__calorias, self.verificar_saudavel()))
        conn.commit()
        conn.close()
        print(f"Prato '{self.nome}' inserido no banco de dados.")

    # Método para excluir prato do banco de dados
    @staticmethod
    def excluir_do_banco(prato_id):
        conn = conectar_banco()
        cursor = conn.cursor()
        cursor.execute('DELETE FROM pratos WHERE id = ?', (prato_id,))
        conn.commit()
        conn.close()
        print(f"Prato com ID {prato_id} excluído do banco de dados.")

    # Método para consultar pratos no banco de dados
    @staticmethod
    def consultar_no_banco():
        conn = conectar_banco()
        cursor = conn.cursor()
        cursor.execute('SELECT * FROM pratos')
        pratos = cursor.fetchall()
        if pratos:
            for prato in pratos:
                print(f"ID: {prato[0]}, Nome: {prato[1]}, Ingredientes: {prato[2]}, Calorias: {prato[3]}, Saudável: {'Sim' if prato[4] else 'Não'}")
        else:
            print("Nenhum prato encontrado no banco de dados.")
        conn.close()

# --------------------------------------------------------------
# Subclasse PratoVegetariano herda de Prato
class PratoVegetariano(Prato):
    def __init__(self, nome, ingredientes, calorias, tipo_vegetariano):
        super().__init__(nome, ingredientes, calorias)  # Chamando o construtor da classe Pai
        self.tipo_vegetariano = tipo_vegetariano

    # Sobrescrevendo o método exibir_dados para personalizar a exibição
    def exibir_dados(self):
        print(f"Prato Vegetariano: {self.nome}")
        print(f"Ingredientes: {self.ingredientes}")
        print(f"Calorias: {self.get_calorias()} kcal")
        print(f"Tipo de prato: {self.tipo_vegetariano}")

# --------------------------------------------------------------
# Função para testar a funcionalidade do sistema
def testar_sistema():
    # Criando objetos da classe Prato (pratos comuns)
    prato1 = Prato("Arroz com Feijão", "Arroz, Feijão, Carne, Salada", 450)
    prato2 = Prato("Macarrão à Bolonhesa", "Macarrão, Carne Moída, Molho de Tomate, Queijo", 600)

    # Criando objetos da subclasse PratoVegetariano (pratos vegetarianos)
    prato_vegetariano1 = PratoVegetariano("Feijoada Vegetariana", "Feijão, Tofu, Legumes", 350, "Vegana")
    prato_vegetariano2 = PratoVegetariano("Lasanha de Abobrinha", "Abobrinha, Queijo, Molho de Tomate, Espinafre", 400, "Vegetariana")

    # Inserindo pratos no banco de dados
    prato1.inserir_no_banco()
    prato2.inserir_no_banco()
    prato_vegetariano1.inserir_no_banco()
    prato_vegetariano2.inserir_no_banco()

    # Consultando pratos no banco de dados
    print("\nConsultando pratos no banco de dados:")
    Prato.consultar_no_banco()

    # Atualizando calorias usando o set
    prato1.set_calorias(500)
    prato2.set_calorias(550)

    # Excluindo um prato do banco de dados (ID 1)
    Prato.excluir_do_banco(1)

    # Consultando pratos novamente após a exclusão
    print("\nConsultando pratos após exclusão:")
    Prato.consultar_no_banco()

    # Exibindo dados usando polimorfismo
    print("\nExibindo dados dos pratos:")
    prato1.exibir_dados()
    prato2.exibir_dados()
    prato_vegetariano1.exibir_dados()
    prato_vegetariano2.exibir_dados()

# --------------------------------------------------------------
# Função principal para executar o sistema
if __name__ == "__main__":
    # Criando a tabela no banco de dados
    criar_tabela()

    # Testando a funcionalidade do sistema
    testar_sistema()
